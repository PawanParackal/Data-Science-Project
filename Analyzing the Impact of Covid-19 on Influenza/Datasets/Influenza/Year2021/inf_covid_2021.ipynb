# %%
df1 = read.csv("4Jan - 17Jan 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df2 = read.csv("18Jan - 31Jan 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df3 = read.csv("1Feb - 14Feb 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df4 = read.csv("15Feb - 28Feb 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df5 = read.csv("1Mar - 14Mar 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df6 = read.csv("15Mar - 28Mar 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df7 = read.csv("29Mar - 11Apr 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df8 = read.csv("12Apr - 25Apr 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df9 = read.csv("26Apr - 9May 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df10 = read.csv("10May - 23May 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df11 = read.csv("24May - 6Jun 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df12 = read.csv("7Jun - 20Jun 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df13 = read.csv("21Jun - 4Jul 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df14 = read.csv("5Jul - 18Jul 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df15 = read.csv("19Jul - 1Aug 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df16 = read.csv("2Aug - 15Aug 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df17 = read.csv("16Aug - 29Aug 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df18 = read.csv("30Aug - 12Sep 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df19 = read.csv("13Sep - 26Sep 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df20 = read.csv("27Sep - 10Oct 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df21 = read.csv("11Oct - 24Oct 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df22 = read.csv("25Oct - 7Dec 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df23 = read.csv("8Nov - 21Nov 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df24 = read.csv("22Nov - 5Dec 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df25 = read.csv("6Dec - 19Dec 2021.csv", header=TRUE, stringsAsFactors=FALSE)
df26 = read.csv("20Dec 2021 - 2Jan 2022.csv", header=TRUE, stringsAsFactors=FALSE)

# %%
df1 <- df1[, -c(1,3:11, 13:23)]
df2 <- df2[, -c(1,3:11, 13:23)]
df3 <- df3[, -c(1,3:11, 13:23)]
df4 <- df4[, -c(1,3:11, 13:23)]
df5 <- df5[, -c(1,3:11, 13:23)]
df6 <- df6[, -c(1,3:11, 13:23)]
df7 <- df7[, -c(1,3:11, 13:23)]
df8 <- df8[, -c(1,3:11, 13:23)]
df9 <- df9[, -c(1,3:11, 13:23)]
df10 <- df10[, -c(1,3:11, 13:23)]
df11 <- df11[, -c(1,3:11, 13:23)]
df12 <- df12[, -c(1,3:11, 13:23)]
df13 <- df13[, -c(1,3:11, 13:23)]
df14 <- df14[, -c(1,3:11, 13:23)]
df15 <- df15[, -c(1,3:11, 13:23)]
df16 <- df16[, -c(1,3:11, 13:23)]
df17 <- df17[, -c(1,3:11, 13:23)]
df18 <- df18[, -c(1,3:11, 13:23)]
df19 <- df19[, -c(1,3:11, 13:23)]
df20 <- df20[, -c(1,3:11, 13:23)]
df21 <- df21[, -c(1,3:11, 13:23)]
df22 <- df22[, -c(1,3:11, 13:23)]
df23 <- df23[, -c(1,3:11, 13:23)]
df24 <- df24[, -c(1,3:11, 13:23)]
df25 <- df25[, -c(1,3:11, 13:23)]
df26 <- df26[, -c(1,3:11, 13:23)]

# %%
inf1 <- df1[grep("Influenza", df1$X),]
inf2 <- df2[grep("Influenza", df2$X),]
inf3 <- df3[grep("Influenza", df3$X),]
inf4 <- df4[grep("Influenza", df4$X),]
inf5 <- df5[grep("Influenza", df5$X),]
inf6 <- df6[grep("Influenza", df6$X),]
inf7 <- df7[grep("Influenza", df7$X),]
inf8 <- df8[grep("Influenza", df8$X),]
inf9 <- df9[grep("Influenza", df9$X),]
inf10 <- df10[grep("Influenza", df10$X),]
inf11 <- df11[grep("Influenza", df11$X),]
inf12 <- df12[grep("Influenza", df12$X),]
inf13 <- df13[grep("Influenza", df13$X),]
inf14 <- df14[grep("Influenza", df14$X),]
inf15 <- df15[grep("Influenza", df15$X),]
inf16 <- df16[grep("Influenza", df16$X),]
inf17 <- df17[grep("Influenza", df17$X),]
inf18 <- df18[grep("Influenza", df18$X),]
inf19 <- df19[grep("Influenza", df19$X),]
inf20 <- df20[grep("Influenza", df20$X),]
inf21 <- df21[grep("Influenza", df21$X),]
inf22 <- df22[grep("Influenza", df22$X),]
inf23 <- df23[grep("Influenza", df23$X),]
inf24 <- df24[grep("Influenza", df24$X),]
inf25 <- df25[grep("Influenza", df25$X),]
inf26 <- df26[grep("Influenza", df26$X),]

# %%
covid1 <- df1[grep("COVID", df1$X),]
covid2 <- df2[grep("COVID", df2$X),]
covid3 <- df3[grep("COVID", df3$X),]
covid4 <- df4[grep("COVID", df4$X),]
covid5 <- df5[grep("COVID", df5$X),]
covid6 <- df6[grep("COVID", df6$X),]
covid7 <- df7[grep("COVID", df7$X),]
covid8 <- df8[grep("COVID", df8$X),]
covid9 <- df9[grep("COVID", df9$X),]
covid10 <- df10[grep("COVID", df10$X),]
covid11 <- df11[grep("COVID", df11$X),]
covid12 <- df12[grep("COVID", df12$X),]
covid13 <- df13[grep("COVID", df13$X),]
covid14 <- df14[grep("COVID", df14$X),]
covid15 <- df15[grep("COVID", df15$X),]
covid16 <- df16[grep("COVID", df16$X),]
covid17 <- df17[grep("COVID", df17$X),]
covid18 <- df18[grep("COVID", df18$X),]
covid19 <- df19[grep("COVID", df19$X),]
covid20 <- df20[grep("COVID", df20$X),]
covid21 <- df21[grep("COVID", df21$X),]
covid22 <- df22[grep("COVID", df22$X),]
covid23 <- df23[grep("COVID", df23$X),]
covid24 <- df24[grep("COVID", df24$X),]
covid25 <- df25[grep("COVID", df25$X),]
covid26 <- df26[grep("COVID", df26$X),]

# %%
df1x <- rbind(inf1, covid1)
df2x <- rbind(inf2, covid2)
df3x <- rbind(inf3, covid3)
df4x <- rbind(inf4, covid4)
df5x <- rbind(inf5, covid5)
df6x <- rbind(inf6, covid6)
df7x <- rbind(inf7, covid7)
df8x <- rbind(inf8, covid8)
df9x <- rbind(inf9, covid9)
df10x <- rbind(inf10, covid10)
df11x <- rbind(inf11, covid11)
df12x <- rbind(inf12, covid12)
df13x <- rbind(inf13, covid13)
df14x <- rbind(inf14, covid14)
df15x <- rbind(inf15, covid15)
df16x <- rbind(inf16, covid16)
df17x <- rbind(inf17, covid17)
df18x <- rbind(inf18, covid18)
df19x <- rbind(inf19, covid19)
df20x <- rbind(inf20, covid20)
df21x <- rbind(inf21, covid21)
df22x <- rbind(inf22, covid22)
df23x <- rbind(inf23, covid23)
df24x <- rbind(inf24, covid24)
df25x <- rbind(inf25, covid25)
df26x <- rbind(inf26, covid26)

# %%
df1x$X.9 <- gsub(",", "", df1x$X.9)
df2x$X.9 <- gsub(",", "", df2x$X.9)
df3x$X.9 <- gsub(",", "", df3x$X.9)
df4x$X.9 <- gsub(",", "", df4x$X.9)
df5x$X.9 <- gsub(",", "", df5x$X.9)
df6x$X.9 <- gsub(",", "", df6x$X.9)
df7x$X.9 <- gsub(",", "", df7x$X.9)
df8x$X.9 <- gsub(",", "", df8x$X.9)
df9x$X.9 <- gsub(",", "", df9x$X.9)
df10x$X.9 <- gsub(",", "", df10x$X.9)
df11x$X.9 <- gsub(",", "", df11x$X.9)
df12x$X.9 <- gsub(",", "", df12x$X.9)
df13x$X.9 <- gsub(",", "", df13x$X.9)
df14x$X.9 <- gsub(",", "", df14x$X.9)
df15x$X.9 <- gsub(",", "", df15x$X.9)
df16x$X.9 <- gsub(",", "", df16x$X.9)
df17x$X.9 <- gsub(",", "", df17x$X.9)
df18x$X.9 <- gsub(",", "", df18x$X.9)
df19x$X.9 <- gsub(",", "", df19x$X.9)
df20x$X.9 <- gsub(",", "", df20x$X.9)
df21x$X.9 <- gsub(",", "", df21x$X.9)
df22x$X.9 <- gsub(",", "", df22x$X.9)
df23x$X.9 <- gsub(",", "", df23x$X.9)
df24x$X.9 <- gsub(",", "", df24x$X.9)
df25x$X.9 <- gsub(",", "", df25x$X.9)
df26x$X.9 <- gsub(",", "", df26x$X.9)

# %%
df1x[,2] <- as.numeric(df1x[,2])
df2x[,2] <- as.numeric(df2x[,2])
df3x[,2] <- as.numeric(df3x[,2])
df4x[,2] <- as.numeric(df4x[,2])
df5x[,2] <- as.numeric(df5x[,2])
df6x[,2] <- as.numeric(df6x[,2])
df7x[,2] <- as.numeric(df7x[,2])
df8x[,2] <- as.numeric(df8x[,2])
df9x[,2] <- as.numeric(df9x[,2])
df10x[,2] <- as.numeric(df10x[,2])
df11x[,2] <- as.numeric(df11x[,2])
df12x[,2] <- as.numeric(df12x[,2])
df13x[,2] <- as.numeric(df13x[,2])
df14x[,2] <- as.numeric(df14x[,2])
df15x[,2] <- as.numeric(df15x[,2])
df16x[,2] <- as.numeric(df16x[,2])
df17x[,2] <- as.numeric(df17x[,2])
df18x[,2] <- as.numeric(df18x[,2])
df19x[,2] <- as.numeric(df19x[,2])
df20x[,2] <- as.numeric(df20x[,2])
df21x[,2] <- as.numeric(df21x[,2])
df22x[,2] <- as.numeric(df22x[,2])
df23x[,2] <- as.numeric(df23x[,2])
df24x[,2] <- as.numeric(df24x[,2])
df25x[,2] <- as.numeric(df25x[,2])
df26x[,2] <- as.numeric(df26x[,2])

# %%
colnames(df1x) <- c("Disease", "4Jan - 17Jan 2021")
colnames(df2x) <- c("Disease", "18Jan - 31Jan 2021")
colnames(df3x) <- c("Disease", "1Feb - 14Feb 2021")
colnames(df4x) <- c("Disease", "15Feb - 28Feb 2021")
colnames(df5x) <- c("Disease", "1Mar - 14Mar 2021")
colnames(df6x) <- c("Disease", "15Mar - 28Mar 2021")
colnames(df7x) <- c("Disease", "29Mar - 11Apr 2021")
colnames(df8x) <- c("Disease", "12Apr - 25Apr 2021")
colnames(df9x) <- c("Disease", "26Apr - 9May 2021")
colnames(df10x) <- c("Disease", "10May - 23May 2021")
colnames(df11x) <- c("Disease", "24May - 6Jun 2021")
colnames(df12x) <- c("Disease", "7Jun - 20Jun 2021")
colnames(df13x) <- c("Disease", "21Jun - 4Jul 2021")
colnames(df14x) <- c("Disease", "5Jul - 18Jul 2021")
colnames(df15x) <- c("Disease", "19Jul - 1Aug 2021")
colnames(df16x) <- c("Disease", "2Aug - 15Aug 2021")
colnames(df17x) <- c("Disease", "16Aug - 29Aug 2021")
colnames(df18x) <- c("Disease", "30Aug - 12Sep 2021")
colnames(df19x) <- c("Disease", "13Sep - 26Sep 2021")
colnames(df20x) <- c("Disease", "27Sep - 10Oct 2021")
colnames(df21x) <- c("Disease", "11Oct - 24Oct 2021")
colnames(df22x) <- c("Disease", "25Oct - 7Dec 2021")
colnames(df23x) <- c("Disease", "8Nov - 21Nov 2021")
colnames(df24x) <- c("Disease", "22Nov - 5Dec 2021")
colnames(df25x) <- c("Disease", "6Dec - 19Dec 2021")
colnames(df26x) <- c("Disease", "20Dec 2021 - 2Jan 2022")

# %%
combined_table_2022 <- cbind(df1x, df2x[,2], df3x[,2], df4x[,2], df5x[,2], df6x[,2], df7x[,2], df8x[,2], df9x[,2], df10x[,2]
                             , df11x[,2], df12x[,2], df13x[,2], df14x[,2], df15x[,2], df16x[,2], df17x[,2], df18x[,2], df19x[,2]
                             , df20x[,2], df21x[,2], df22x[,2], df23x[,2], df24x[,2], df25x[,2], df26x[,2])
combined_table_2022
# Out:
#    Disease                          4Jan - 17Jan 2021 df2x[, 2] df3x[, 2]
# 40 Influenza (laboratory confirmed)  37                29        30
# 23 COVID-19**                       231               107       100
#    df4x[, 2] df5x[, 2] df6x[, 2] df7x[, 2] df8x[, 2] df9x[, 2] ⋯ df17x[, 2]
# 40 19         40       19         29        37        23       ⋯    22
# 23 84        156       84        155       298       249       ⋯ 13302
#    df18x[, 2] df19x[, 2] df20x[, 2] df21x[, 2] df22x[, 2] df23x[, 2] df24x[, 2]
# 40    28         27         20         28         19         37         29
# 23 22776      23986      30733      30798      21344      18060      19335
#    df25x[, 2] df26x[, 2]
# 40    43          30
# 23 32930      178755

# %%
colnames(combined_table_2022) <- c("Disease", "4Jan - 17Jan 2021",
"18Jan - 31Jan 2021",
"1Feb - 14Feb 2021",
"15Feb - 28Feb 2021",
"1Mar - 14Mar 2021",
"15Mar - 28Mar 2021",
"29Mar - 11Apr 2021",
"12Apr - 25Apr 2021",
"26Apr - 9May 2021",
"10May - 23May 2021",
"24May - 6Jun 2021",
"7Jun - 20Jun 2021",
"21Jun - 4Jul 2021",
"5Jul - 18Jul 2021",
"19Jul - 1Aug 2021",
"2Aug - 15Aug 2021",
"16Aug - 29Aug 2021",
"30Aug - 12Sep 2021",
"13Sep - 26Sep 2021",
"27Sep - 10Oct 2021",
"11Oct - 24Oct 2021",
"25Oct - 7Dec 2021",
"8Nov - 21Nov 2021",
"22Nov - 5Dec 2021",
"6Dec - 19Dec 2021",
"20Dec 2021 - 2Jan 2022")
combined_table_2022
# Out:
#    Disease                          4Jan - 17Jan 2021 18Jan - 31Jan 2021
# 40 Influenza (laboratory confirmed)  37                29
# 23 COVID-19**                       231               107
#    1Feb - 14Feb 2021 15Feb - 28Feb 2021 1Mar - 14Mar 2021 15Mar - 28Mar 2021
# 40  30               19                  40               19
# 23 100               84                 156               84
#    29Mar - 11Apr 2021 12Apr - 25Apr 2021 26Apr - 9May 2021 ⋯ 16Aug - 29Aug 2021
# 40  29                 37                 23               ⋯    22
# 23 155                298                249               ⋯ 13302
#    30Aug - 12Sep 2021 13Sep - 26Sep 2021 27Sep - 10Oct 2021 11Oct - 24Oct 2021
# 40    28                 27                 20                 28
# 23 22776              23986              30733              30798
#    25Oct - 7Dec 2021 8Nov - 21Nov 2021 22Nov - 5Dec 2021 6Dec - 19Dec 2021
# 40    19                37                29                43
# ...
